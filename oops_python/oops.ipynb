# %% [markdown]
# # Classes and Objects
#
# object-oriented programming (oop) is a programming paradigm that uses "objects" to design applications and computer programs.OOP allows for modeling real-world scenarios using classes and objects.

# %%
# A class is a blue print for creating objects.Attributes,methods
# declaring a class
class car:
    pass
# declaring object of the class
audi=car()
bmw=car()

print(type(audi))
# Out:
# <class '__main__.car'>

# %%
print(audi)
print(bmw)

# %%
# method of declaring attributes
audi.windows=4

print(audi.windows)
# Out:
# 4

# %%
tata=car()
tata.doors=4
print(tata.windows)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 3
#       1 tata=car()
#       2 tata.doors=4
# ----> 3 print(tata.windows)
#
# AttributeError: 'car' object has no attribute 'windows'

# %%
print(tata.doors)
# Out:
# 4

# %%
dir(tata)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'doors']

# %%
# Instance Variable and Methods
class Dog:
    ## constructure 
    # with the help of this i am able to declar all the attributes that available in the class
    def __init__(self,name,age):
        self.name=name
        self.age=age

# create objects
dog1=Dog("Buddy",3)
print(dog1)
print(dog1.name)
print(dog1.age)
# Out:
# ...
# Buddy
# 3

# %%
dog2=Dog('Lucy',4)
print(dog2.name)
print(dog2.age)
# Out:
# Lucy
# 4

# %%
# Define a class with instance method
class Dog:
    # declaring instance attributes
    def __init__(self,name,age):
        self.name=name
        self.age=age

    # creating instance methods
    def bark(self):
        print(f"{self.name} says woof")

# creating objects
dog1=Dog("Buddy",3)
dog1.bark()
dog2=Dog('Lucy',4)
dog2.bark()
# Out:
# Buddy says woof
# Lucy says woof

# %%
# modeling a bank account

# define a class for bank account
class BankAccount:
    # creating attributes of the banckaccount
    def __init__(self,owner,balance=0): #bydefult balance of the account is 0
        self.owner=owner
        self.balance=balance

    # creating instance methods

    def deposite(self,amount):
        self.balance+=amount
        print(f"{amount} is deposited . New balance is {self.balance}")

    def withdraw(self,amount):
        if amount>self.balance:
            print("insufficent balance!")
        else:
            self.balance-=amount
            print(f"{amount} is withdraw.new balance is {self.balance}")

    def get_balance(self):
        return self.balance

# creating object 
account=BankAccount("Basudha",5000)
print(account.balance)
# Out:
# 5000

# %%
# call the instance methods
account.deposite(100)
# Out:
# 100 is deposited . New balance is 5100

# %%
account.withdraw(300)
# Out:
# 300 is withdraw.new balance is 4800

# %%
print(account.get_balance())
# Out:
# 4800
